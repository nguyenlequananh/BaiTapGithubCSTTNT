# %%
import numpy as np
import matplotlib.pyplot as plt

# Sinh dữ liệu hàm số
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

# Kiểm tra dữ liệu đầu ra
print(f'+ X: |X|={len(X)}, x in [{np.min(X):.2f}, {np.max(X):.2f}], 10 samples: {X[:10]}')
print(f'+ Cos(X): |C|={len(C)}, C in [{np.min(C):.2f}, {np.max(C):.2f}], 10 samples: {C[:10]}')
print(f'+ Sin(X): |S|={len(S)}, S in [{np.min(S):.2f}, {np.max(S):.2f}], 10 samples: {S[:10]}')

# Hiển thị đồ thị
plt.figure(figsize=(8, 5))
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cos(x)")
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-", label="sin(x)")

# Giới hạn trục x
plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.xticks(
    [-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
    [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$']
)

# Giới hạn trục y
plt.ylim(-1.1, 1.1)
plt.yticks([-1, 0, +1], [r'$-1$', r'$0$', r'$+1$'])

# Thêm chú thích và lưới
plt.axhline(y=0, color='black', linewidth=1, linestyle="--", alpha=0.6)
plt.axvline(x=0, color='black', linewidth=1, linestyle="--", alpha=0.6)
plt.legend()
plt.title("Đồ thị của sin(x) và cos(x)")
plt.grid(alpha=0.3)
# Out:
# + X: |X|=256, x in [-3.14, 3.14], 10 samples: [-3.14159265 -3.11695271 -3.09231277 -3.06767283 -3.04303288 -3.01839294
#  -2.993753   -2.96911306 -2.94447311 -2.91983317]
# + Cos(X): |C|=256, C in [-1.00, 1.00], 10 samples: [-1.         -0.99969645 -0.99878599 -0.99726917 -0.99514692 -0.99242051
#  -0.98909161 -0.98516223 -0.98063477 -0.97551197]
# + Sin(X): |S|=256, S in [-1.00, 1.00], 10 samples: [-1.22464680e-16 -2.46374492e-02 -4.92599411e-02 -7.38525275e-02
#  -9.84002783e-02 -1.22888291e-01 -1.47301698e-01 -1.71625679e-01
#  -1.95845467e-01 -2.19946358e-01]
